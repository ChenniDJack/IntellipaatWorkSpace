# %% [markdown]
# # Data Visualization Guid

# %% [markdown]
# <h3>Author: Chenni Veera S</h3>

# %% [markdown]
# <h2>What is data Visualization? </h2>
# <ul>
#   <li>Data  Visualization is the Graphical representation of information and data</li>
#   <li>By using visual elements like charts, graphs and maps, data visualization tools provide an accessible way to see and understand trands, outliers and patterns in data</li>
# </ul>

# %% [markdown]
# <h2>Important Libraries for Data Visualization in python</h2>
# <ul>
#   <li>Matplotlib</li>
#   <li>Seaborn</li>
#   <li>plotly</li>
#   <li>Bokeh</li>
#   <li>Altair</li>
#   <li>ggplot</li>
#   <li>pygal</li>
#   <li>Geoplotlib</li>
#   <li>Gleam</li>
#   <li>Missingno</li>
#   <li>Leather</li>
#   <li>Wordcloud</li>
#   <li>Venn</li>
# </ul>

# %% [markdown]
# <h2>Grammer of Graphics for plotting in Python</h2>
# <ul>
#   <li><b>Data:</b> The data to be visualized</li>
#   <li><b>Aesthetics:</b> The visual properties of the data points, such as position, size, shap, color and transparency</li>
#   <li><b>Geometry:</b> The geometric shapes used to represent the data points such as bars, line, and points</li>
#   <li><b>Facets:</b> The arrangement of the data into subset such os rows, columns or panels</li>
#   <li><b>Statistics:</b> The statistical transformations applied to the data such as aggregations, smoothing and modeling</li>
#   <li><b>Scales:</b> The Mapping of data values to visual properties such as axis limits, tick marks and color scales</li>
#   <li><b>Themes:</b> The overall visual appearance of the plot such as colors, fonts and gridlines</li>
#   <li><b>Guides:</b> The visual elements used to assist in reading the plot such as legends, axes and labels</li>
#   <li><b>Interactivity:</b> The interactive features of the plot such as tooltips, zooming and panning</li>
#   <li><b>Annotations:</b> The textual and graphical annotations used to highlight specific aspects of the plot</li>
#   <li><b>Extensions:</b> The additional features and plugins that enhance the plot such as animations, sliders and widgents</li>
# </ul>

# %% [markdown]
# ## Parts of a plot
# <ul>
#     <li>Title</li>
#     <li>Axis Labels</li>
#     <li>Tick Marks</li>
#     <li>Gridlines</li>
#     <li>Legends</li>
#     <li>Data Points</li>
#     <li>data Labels</li>
#     <li>Annotations</li>
#     <li>Background</li>
# </ul>

# %% [markdown]
# ## Data Visualization with Matplotlib and Seaborn

# %% [markdown]
# ### Loading the Libraries and data

# %%
# load the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import get_ipython
ipython = get_ipython()
ipython.run_line_magic("time", "a = sum(range(1000000))")
# %%timeit
import seaborn as sns
# Out:
# CPU times: total: 15.6 ms
# Wall time: 33.4 ms

# %%
data = pd.read_csv("../DataSet/diamonds.csv", delimiter=",")

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.drop(columns=["Unnamed: 0"], inplace=True)

# %% [markdown]
# ## Explain each part of diamonds dataset
#
# <p>A data frame which 53,940 rows and 10 variables</p>
#
# <ui>
#     <li><b>price: </b>price in US dollars (\$326--\$18,823) </li>
#     <li><b>carat: </b>weight of the diamond (0.2--5.01) </li>
#     <li><b>cut: </b> quality of the cut (Fair, Good, Very Good, Premium, Ideal) </li>
#     <li><b>color: </b>diamond colour, from J (worst) to D (best) </li>
#     <li><b>clarity: </b>a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)) </li>
#     <li><b>x: </b>length in mm (0--10.74) </li>
#     <li><b>y: </b>width in mm (0--58.9)</li>
#     <li><b>z: </b>depth in mm (0--31.8) </li>
#     <li><b>depth: </b>total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79) </li>
#     <li><b>table: </b>width of top of diamond relative to widest point (43--95) </li>
# </ui>

# %%
plt.plot(data["carat"], data["price"])
plt.title("Carat vs Price Line Plot")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(data["carat"], data["price"])
plt.title("Carat vs Price Scatter Plot")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.show()

# %%
plt.bar(data["cut"].unique(), data.groupby("cut")["price"].mean())
plt.title("Average Price By cut")
plt.xlabel("Cut Types")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
#  ## Intermediate Plots using Matplotlib

# %%
# Histogram
plt.hist(data["price"],bins=100, edgecolor="black")
plt.title("Distribution of Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# box plot
plt.boxplot(data["carat"], vert=False) # Horizontel chart
plt.title("Box Plot of Carat")
plt.xlabel("Carat")
plt.show()

# %%
# Pie Chart

cut_count = data["cut"].value_counts()
plt.pie(cut_count, labels=cut_count.index, autopct="%1.1f%%", startangle=90)
plt.title("Distribution of cut Quality")
plt.show()

# %%
# Heatmap of Correlation Matrix
correlation = data[["carat", "depth", "table", "price", "x", "y", "z"]].corr()
plt.imshow(correlation, cmap="coolwarm", interpolation="none")
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation)), correlation.columns)
plt.title("Heatmap of Correlation matrix")
plt.show()

# cmap vales: 'Accent', 'Accent_r', 'Blues', 'Blues_r', 
#     'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 
#     'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 
#     'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 
#     'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 
#     'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 
#     'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 
#     'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 
#     'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 
#     'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 
#     'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 
#     'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 
#     'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 
#     'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 
#     'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 
#     'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 
#     'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 
#     'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 
#     'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r',
#     'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 
#     'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 
#     'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 
#     'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 
#     'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 
#     'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 
#     'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 
#     'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 
#     'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 
#     'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 
#     'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 
#     'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 
#     'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 
#     'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 
#     'turbo', 'turbo_r', 'twilight', 'twilight_r', 
#     'twilight_shifted', 'twilight_shifted_r', 'viridis', 
#     'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
sns.heatmap(correlation, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))
ax[0].hist(data["carat"], bins=10, edgecolor="black")
ax[0].set_title("Histogram of Carat")
ax[0].set_xlabel("Carat")
ax[1].hist(data["price"], bins=10, edgecolor="black")
ax[1].set_title("Histogram of Price")
ax[1].set_xlabel("Price")
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(12,8))
ax[0,0].hist(data["carat"], bins=10, edgecolor="black")
ax[0,0].set_title("Histogram of Carat")
ax[0,0].set_xlabel("Carat")
ax[0,1].hist(data["price"], bins=10, edgecolor="black")
ax[0,1].set_title("Histogram of Price")
ax[0,1].set_xlabel("Price")

ax[1,0].scatter(data["carat"], data["price"])
ax[1,0].set_title("Scatter Plot of Carat vs Price")
ax[1,0].set_xlabel("Carat")
ax[1,0].set_ylabel("price")


ax[1,1].bar(data["cut"].unique(), data.groupby("cut")["price"].mean())
ax[1,1].set_title("Average price by cut")
ax[1,1].set_xlabel("Types of Cut")
ax[1,1].set_ylabel("Average Prive")
plt.show()

# %%
sns.scatterplot(x="carat", y="price", data=data)
plt.title("Seaborn Scatter Plot of Carat vs Price")
plt.show()

# %%
sns.scatterplot(x="carat", y="price", data=data, hue="cut")
plt.title("Seaborn Scatter Plot of Carat vs Price")
plt.show()

# %%
sns.lineplot(x="carat", y="price", data=data)
plt.title("Seaborn line Plot of Carat vs Price")
plt.show()

# %%
sns.lineplot(x="carat", y="price", data=data, hue="cut")
plt.title("Seaborn line Plot of Carat vs Price")
plt.show()

# %%
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
unique_classes = data['cut'].unique()
data_by_class = {cut: data[data['cut'] == cut] for cut in unique_classes}
ideal_data = data_by_class["Ideal"]
premium_data = data_by_class["Premium"]
good_data = data_by_class["Good"]
very_good_data = data_by_class["Very Good"]
Fair_data = data_by_class["Fair"]

# %%
fig, ax = plt.subplots(5,1, figsize=(11,10))
sns.lineplot(x="carat", y="price", ax=ax[0], hue="cut", data=ideal_data, palette=['r'])
sns.lineplot(x="carat", y="price", ax=ax[1], hue="cut", data=premium_data, palette=['r'])
sns.lineplot(x="carat", y="price", ax=ax[2], hue="cut", data=good_data, palette=['r'])
sns.lineplot(x="carat", y="price", ax=ax[3], hue="cut", data=very_good_data, palette=['r'])
sns.lineplot(x="carat", y="price", ax=ax[4], hue="cut", data=Fair_data, palette=['r'])
# fig.delaxes(ax[1,2])
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="seaborn")
g = sns.FacetGrid(data, col="cut", col_wrap = 3, height=4)
g.map(sns.lineplot, "carat", "price")
g.add_legend()
plt.show()

# %%
sns.boxplot(x = "cut", y = "price", data = data)
plt.title("Box Plot of Price by cut")
plt.show()

# %%
sns.boxplot(x = "cut", y = "price", data = data, hue="color")
plt.title("Box Plot of Price by cut")
plt.show()

# %%
sns.violinplot(x = "cut", y= "price", data=data)
plt.title("Violin Plot of Price by cut")
plt.show()

# %%
sns.violinplot(x = "color", y= "price", data=data)
plt.title("Violin Plot of Price by color")
plt.show()

# %%
sns.countplot(x="cut", data=data)
plt.title("Count Plot of Cut")
plt.show()

# %%
fig = plt.figure(figsize=(12,3))
sns.countplot(x="cut", data=data, hue="color")
plt.title("Count Plot of Cut")
plt.show()

# %%
sns.heatmap(data[["carat", "depth", "table", "price", "x", "y", "z"]].corr(), annot=True, cmap="coolwarm")
plt.title("Seaborn heatmap of Correlation Matrix")
plt.show()

# %%
sns.pairplot(data, hue="cut")
plt.title("Pair Plot of Diamand Attributes")
plt.show()

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
g = sns.FacetGrid(data, col="color", col_wrap=3)
g.map(sns.histplot, "price", bins=10, edgecolor="black")
plt.show()

# %% [markdown]
# ## Enhancing Plots with Seaborn for Report-Ready Visualizations

# %%
sns.set_style("darkgrid") # Options: white, dark, whitegrid, darkgrid, ticks
sns.set_context("notebook") # Options: Paper, notebook, talk, poster 

sns.scatterplot(x="carat", y="price", data=data)
plt.title("Scatter Plot with whitegrid styoe and notbook context")
plt.show()

# %%
sns.set_style("dark")
sns.lineplot(x="carat", y="price", data=data)
plt.show()

# %%
sns.set_context("notebook", font_scale=1.5)
sns.boxplot(x='cut', y='price', data=data)
plt.title("Box Plot with Talk Context and Larger Font Scale")
plt.show()

# %%
fig = plt.figure(figsize=(12,3))
sns.set_context("notebook")
sns.set_palette("pastel") # options: deep, muted, bright, pastel, dark, colorblind
sns.violinplot(x='color', y="price", data=data, hue="cut")
plt.title("Violin Plot with Pastel Color Palette")
plt.show()

# %%
# Creating and using a custom color palette
custom_palette = sns.color_palette(['#e74c3c',  # Red
           '#3498db',  # Blue
           '#2ecc71',  # Green
           '#f1c40f',  # Yellow/Gold
           '#9b59b6'] )# Purple
sns.set_palette(custom_palette)
sns.countplot(x="cut", data=data, hue="color")
plt.title("Count Plot with Custom Color Palette")
plt.show()

# %%
# Adding ridlines to the background

sns.set_style("whitegrid")
sns.scatterplot(x='carat', y='price', data=data)
plt.grid(True, linestyle="-", alpha=0.5)
plt.title("Scatter Plot with Gridlines")
plt.show()

# %%
# Removind spines from the plot for a cleaner look

sns.set_style("white")
ax = sns.histplot(data["price"], bins=10, edgecolor="black")
sns.despine() # Remove the top and right spines?
plt.title("Histogram with spines Removed")
plt.show()

# %%
data2 = data.loc[:10]

# %%
data2
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73

# %%
sns.scatterplot(x="carat", y="price", data=data2)
plt.title("Scatter Plot with Annotaations")
for i in range(len(data2)):
    plt.annotate(f"${data2['price'][i]}", {data2["carat"][i], data2["price"][i]}, fontsize=8, alpha=0.7)
plt.show()

# %%
# Customizing the lenge
fig = plt.figer
sns.boxplot(x="cut", y='price', data=data)
plt.legend(title="Cut Type", labels=data["cut"].unique(), loc="best", frameon=True)
plt.title("Box Plot with custom Legend")
plt.show()

# Option Loc:
# 'best', 'upper right', 'upper left', 'lower left', 'lower right', 
# 'right', 'center left', 'center right', 'lower center', 
# 'upper center', 'center'
